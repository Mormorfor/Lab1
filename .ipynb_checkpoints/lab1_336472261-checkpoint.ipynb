# %%
import json
import csv
import re

# %%
def iterate_json(item, info_dict, current_key):
    if isinstance(item, list):
        for i,element in enumerate(item):
            iterate_json(element, info_dict, current_key + "." + str(i))
            
    elif isinstance(item, dict):
        for key in item:
            value = item[key]
            new_key = ""
            if current_key != "":
                new_key = current_key + "."
            new_key = new_key + str(key)
            iterate_json(value, info_dict, new_key)
    else:
        info_dict[current_key] = item

# %%
with open('pokedex.json') as jsonfile: 
    data = json.load(jsonfile)
    
with open('pokedex.tsv', 'w') as output:
    tsv_writer = csv.writer(output, delimiter='\t',quotechar='|')
    flat_data = []
    for data_point in data:
        per_item = {}
        iterate_json(data_point, per_item, "")
        flat_data.append(per_item)
    
    pattern_height = r'\((\d+\.\d+)m\)'
    pattern_weight = r'\((\d+\.\d+) kg\)'

    for row in flat_data:

        height = row.get('height', '')
        weight = row.get('weight', '')

        match = re.search(pattern_height, height)

        if match:
            metric_value = match.group(1) + 'm'
            row['height'] = metric_value
        else:
            row['height'] = None

        match = re.search(pattern_weight, weight)
        if match:
            metric_value = match.group(1) + ' kg'
            row['weight'] = metric_value
        else:
            row['weight'] = None

    
    headers = set()
    for item in flat_data:
        headers.update(item.keys())
    headers = sorted(headers)
    
    tsv_writer.writerow(headers)
 
    for row in flat_data:
        row_values = [row.get(header, '') for header in headers]
        tsv_writer.writerow(row_values)

# %%
with open('pokedex.tsv') as csvfile:
    reader = csv.reader(csvfile, delimiter="\t", quotechar='|')
    for row in reader:
        print('; '.join(row))
# Out:
# abilities.0; abilities.1; abilities.2; abilities.3; abilities.4; abilities.5; description; evolution.0; evolution.1; evolution.2; evolution.3; gen; height; id; name; species; stats.attack; stats.defense; stats.hp; stats.sp.atk; stats.sp.def; stats.speed; stats.total; type.0; type.1; weight
#
# Overgrow; Chlorophyll; ; ; ; ; For some time after its birth, it grows by gaining nourishment from the seed on its back.; Bulbasaur; Ivysaur; Venusaur; ; 1; 0.71m; 001; Bulbasaur; Seed Pokemon; 49; 49; 45; 65; 65; 45; 318; Grass; Poison; 6.9 kg
#
# Overgrow; Chlorophyll; ; ; ; ; When the bud on its back starts swelling, a sweet aroma wafts to indicate the flowers coming bloom.; Bulbasaur; Ivysaur; Venusaur; ; 1; 0.99m; 002; Ivysaur; Seed Pokemon; 62; 63; 60; 80; 80; 60; 405; Grass; Poison; 13.0 kg
#
# Overgrow; Chlorophyll; ; ; ; ; After a rainy day, the flower on its back smells stronger. The scent attracts other Pokemon.; Bulbasaur; Ivysaur; Venusaur; ; 1; 2.01m; 003; Venusaur; Seed Pokemon; 82; 83; 80; 100; 100; 80; 525; Grass; Poison; 100.0 kg
#
# Blaze; Solar Power; ; ; ; ; The fire on the tip of its tail is a measure of its life. If healthy, its tail burns intensely.; Charmander; Charmeleon; Charizard; ; 1; 0.61m; 004; Charmander; Lizard Pokemon; 52; 43; 39; 60; 50; 65; 309; Fire; ; 8.5 kg
#
# Blaze; Solar Power; ; ; ; ; In the rocky mountains where Charmeleon live, their fiery tails shine at night like stars.; Charmander; Charmeleon; Charizard; ; 1; 1.09m; 005; Charmeleon; Flame Pokemon; 64; 58; 58; 80; 65; 80; 405; Fire; ; 19.0 kg
#
# Blaze; Solar Power; ; ; ; ; It is said that Charizards fire burns hotter if it has experienced harsh battles.; Charmander; Charmeleon; Charizard; ; 1; 1.70m; 006; Charizard; Flame Pokemon; 84; 78; 78; 109; 85; 100; 534; Fire; Flying; 90.5 kg
#
# Torrent; Rain Dish; ; ; ; ; It shelters itself in its shell then strikes back with spouts of water at every opportunity.; Squirtle; Wartortle; Blastoise; ; 1; 0.51m; 007; Squirtle; Tiny Turtle Pokemon; 48; 65; 44; 50; 64; 43; 314; Water; ; 9.0 kg
#
# Torrent; Rain Dish; ; ; ; ; It is said to live 10,000 years. Its furry tail is popular as a symbol of longevity.; Squirtle; Wartortle; Blastoise; ; 1; 0.99m; 008; Wartortle; Turtle Pokemon; 63; 80; 59; 65; 80; 58; 405; Water; ; 22.5 kg
#
# Torrent; Rain Dish; ; ; ; ; The jets of water it spouts from the rocket cannons on its shell can punch through thick steel.; Squirtle; Wartortle; Blastoise; ; 1; 1.60m; 009; Blastoise; Shellfish Pokemon; 83; 100; 79; 85; 105; 78; 530; Water; ; 85.5 kg
#
# Shield Dust; Run Away; ; ; ; ; It releases a stench from its red antenna to repel enemies. It grows by molting repeatedly.; Caterpie; Metapod; Butterfree; ; 1; 0.30m; 010; Caterpie; Worm Pokemon; 30; 35; 45; 20; 20; 45; 195; Bug; ; 2.9 kg
#
# Shed Skin; ; ; ; ; ; A steel-hard shell protects its tender body. It quietly endures hardships while awaiting evolution.; Caterpie; Metapod; Butterfree; ; 1; 0.71m; 011; Metapod; Cocoon Pokemon; 20; 55; 50; 25; 25; 30; 205; Bug; ; 9.9 kg
#
# Compound Eyes; Tinted Lens; ; ; ; ; It loves the honey of flowers and can locate flower patches that have even tiny amounts of pollen.; Caterpie; Metapod; Butterfree; ; 1; 1.09m; 012; Butterfree; Butterfly Pokemon; 45; 50; 60; 90; 80; 70; 395; Bug; Flying; 32.0 kg
#
# Shield Dust; Run Away; ; ; ; ; It eats its weight in leaves every day. It fends off attackers with the needle on its head.; Weedle; Kakuna; Beedrill; ; 1; 0.30m; 013; Weedle; Hairy Bug Pokemon; 35; 30; 40; 20; 20; 50; 195; Bug; Poison; 3.2 kg
#
# Shed Skin; ; ; ; ; ; While awaiting evolution, it hides from predators under leaves and in nooks of branches.; Weedle; Kakuna; Beedrill; ; 1; 0.61m; 014; Kakuna; Cocoon Pokemon; 25; 50; 45; 25; 25; 35; 205; Bug; Poison; 10.0 kg
#
# Swarm; Sniper; ; ; ; ; Its best attack involves flying around at high speed, striking with poison needles, then flying off.; Weedle; Kakuna; Beedrill; ; 1; 0.99m; 015; Beedrill; Poison Bee Pokemon; 90; 40; 65; 45; 80; 75; 395; Bug; Poison; 29.5 kg
#
# Keen Eye; Tangled Feet; Big Pecks; ; ; ; It is docile and prefers to avoid conflict. If disturbed, however, it can ferociously strike back.; Pidgey; Pidgeotto; Pidgeot; ; 1; 0.30m; 016; Pidgey; Tiny Bird Pokemon; 45; 40; 40; 35; 35; 56; 251; Normal; Flying; 1.8 kg
#
# Keen Eye; Tangled Feet; Big Pecks; ; ; ; It flies over its wide territory in search of prey, downing it with its highly developed claws.; Pidgey; Pidgeotto; Pidgeot; ; 1; 1.09m; 017; Pidgeotto; Bird Pokemon; 60; 55; 63; 50; 50; 71; 349; Normal; Flying; 30.0 kg
#
# Keen Eye; Tangled Feet; Big Pecks; ; ; ; It flies over its wide territory in search of prey, downing it with its highly developed claws.; Pidgey; Pidgeotto; Pidgeot; ; 1; 1.50m; 018; Pidgeot; Bird Pokemon; 80; 75; 83; 70; 70; 101; 479; Normal; Flying; 39.5 kg
#
# Guts; Run Away; Hustle; ; ; ; It searches for food all day. It gnaws on hard objects to wear down its fangs, which grow constantly during its lifetime.; Rattata; Raticate; ; ; 1; 0.30m; 019; Rattata; Mouse Pokemon; 56; 35; 30; 25; 35; 72; 253; Normal; ; 3.5 kg
#
# Guts; Run Away; Hustle; ; ; ; With its long fangs, this surprisingly violent Pokemon can gnaw away even thick concrete with ease.; Rattata; Raticate; ; ; 1; 0.71m; 020; Raticate; Mouse Pokemon; 81; 60; 55; 50; 70; 97; 413; Normal; ; 18.5 kg
#
# Keen Eye; Sniper; ; ; ; ; It flaps its small wings busily to fly. Using its beak, it searches in grass for prey.; Spearow; Fearow; ; ; 1; 0.30m; 021; Spearow; Tiny Bird Pokemon; 60; 30; 40; 31; 31; 70; 262; Normal; Flying; 2.0 kg
#
# Keen Eye; Sniper; ; ; ; ; It has the stamina to fly all day on its broad wings. It fights by using its sharp beak.; Spearow; Fearow; ; ; 1; 1.19m; 022; Fearow; Beak Pokemon; 90; 65; 65; 61; 61; 100; 442; Normal; Flying; 38.0 kg
#
# Intimidate; Shed Skin; Unnerve; ; ; ; It sneaks through grass without making a sound and strikes unsuspecting prey from behind.; Ekans; Arbok; ; ; 1; 2.01m; 023; Ekans; Snake Pokemon; 60; 44; 35; 40; 54; 55; 288; Poison; ; 6.9 kg
#
# Intimidate; Shed Skin; Unnerve; ; ; ; The pattern on its belly is for intimidation. It constricts foes while they are frozen in fear.; Ekans; Arbok; ; ; 1; 3.51m; 024; Arbok; Cobra Pokemon; 85; 69; 60; 65; 79; 80; 438; Poison; ; 65.0 kg
#
# Static; Lightning Rod; ; ; ; ; It occasionally uses an electric shock to recharge a fellow Pikachu that is in a weakened state.; Pikachu; Raichu; ; ; 1; 0.41m; 025; Pikachu; Mouse Pokemon; 55; 40; 35; 50; 50; 90; 320; Electric; ; 6.0 kg
#
# Static; Lightning Rod; ; ; ; ; Its tail discharges electricity into the ground, protecting it from getting shocked.; Pikachu; Raichu; ; ; 1; 0.79m; 026; Raichu; Mouse Pokemon; 90; 55; 60; 90; 80; 110; 485; Electric; ; 30.0 kg
#
# Sand Veil; Sand Rush; ; ; ; ; It digs deep burrows to live in. When in danger, it rolls up its body to withstand attacks.; Sandshrew; Sandslash; ; ; 1; 0.61m; 027; Sandshrew; Mouse Pokemon; 75; 85; 50; 20; 30; 40; 300; Ground; ; 12.0 kg
#
# Sand Veil; Sand Rush; ; ; ; ; The spikes on its body are made up of its hardened hide. It rolls up and attacks foes with its spikes.; Sandshrew; Sandslash; ; ; 1; 0.99m; 028; Sandslash; Mouse Pokemon; 100; 110; 75; 45; 55; 65; 450; Ground; ; 29.5 kg
#
# Poison Point; Rivalry; Hustle; ; ; ; While it does not prefer to fight, even one drop of the poison it secretes from barbs can be fatal.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â€šÂ¬; Nidorina; Nidoqueen; ; 1; 0.41m; 029; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â€šÂ¬; Poison Pin Pokemon; 47; 52; 55; 40; 40; 41; 275; Poison; ; 7.0 kg
#
# Poison Point; Rivalry; Hustle; ; ; ; When it senses danger, it raises all the barbs on its body. These barbs grow slower than Nidorinos.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â€šÂ¬; Nidorina; Nidoqueen; ; 1; 0.79m; 030; Nidorina; Poison Pin Pokemon; 62; 67; 70; 55; 55; 56; 365; Poison; ; 20.0 kg
#
# Poison Point; Rivalry; Sheer Force; ; ; ; Its entire body is armored with hard scales. It will protect the young in its burrow with its life.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â€šÂ¬; Nidorina; Nidoqueen; ; 1; 1.30m; 031; Nidoqueen; Drill Pokemon; 92; 87; 90; 75; 85; 76; 505; Poison; Ground; 60.0 kg
#
# Poison Point; Rivalry; Hustle; ; ; ; It scans its surroundings by raising its ears out of the grass. Its toxic horn is for protection.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â‚¬Å¡; Nidorino; Nidoking; ; 1; 0.51m; 032; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â‚¬Å¡; Poison Pin Pokemon; 57; 40; 46; 40; 40; 50; 273; Poison; ; 9.0 kg
#
# Poison Point; Rivalry; Hustle; ; ; ; It has a violent disposition and stabs foes with its horn, which oozes poison upon impact.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â‚¬Å¡; Nidorino; Nidoking; ; 1; 0.89m; 033; Nidorino; Poison Pin Pokemon; 72; 57; 61; 55; 55; 65; 365; Poison; ; 19.5 kg
#
# Poison Point; Rivalry; Sheer Force; ; ; ; One swing of its mighty tail can snap a telephone pole as if it were a matchstick.; NidoranÃƒÂ¢Ã¢â€žÂ¢Ã¢â‚¬Å¡; Nidorino; Nidoking; ; 1; 1.40m; 034; Nidoking; Drill Pokemon; 102; 77; 81; 85; 75; 85; 505; Poison; Ground; 62.0 kg
#
# Cute Charm; Magic Guard; Friend Guard; ; ; ; On nights with a full moon, Clefairy gather from all over and dance. Bathing in moonlight makes them float.; Cleffa; Clefairy; Clefable; ; 1; 0.61m; 035; Clefairy; Fairy Pokemon; 45; 48; 70; 60; 65; 35; 323; Fairy; ; 7.5 kg
#
# Cute Charm; Magic Guard; Unaware; ; ; ; Their ears are sensitive enough to hear a pin drop from over a mile away, so theyre usually found in quiet places.; Cleffa; Clefairy; Clefable; ; 1; 1.30m; 036; Clefable; Fairy Pokemon; 70; 73; 95; 95; 90; 60; 483; Fairy; ; 40.0 kg
#
# Flash Fire; Drought; ; ; ; ; As each tail grows, its fur becomes more lustrous. When held, it feels slightly warm.; Vulpix; Ninetales; ; ; 1; 0.61m; 037; Vulpix; Fox Pokemon; 41; 40; 38; 50; 65; 65; 299; Fire; ; 9.9 kg
#
# Flash Fire; Drought; ; ; ; ; Each of its nine tails is imbued with supernatural power, and it can live for a thousand years.; Vulpix; Ninetales; ; ; 1; 1.09m; 038; Ninetales; Fox Pokemon; 76; 75; 73; 81; 100; 100; 505; Fire; ; 19.9 kg
#
# Competitive; Cute Charm; Friend Guard; ; ; ; Looking into its cute, round eyes makes it start singing a song so pleasant listeners cant help but fall asleep.; Jigglypuff; Wigglytuff; ; ; 1; 0.51m; 039; Jigglypuff; Balloon Pokemon; 45; 20; 115; 45; 25; 20; 270; Normal; Fairy; 5.5 kg
#
# Competitive; Cute Charm; Frisk; ; ; ; Its fine fur feels so pleasant, those who accidentally touch it cannot take their hands away.; Jigglypuff; Wigglytuff; ; ; 1; 0.99m; 040; Wigglytuff; Balloon Pokemon; 70; 45; 140; 85; 50; 45; 435; Normal; Fairy; 12.0 kg
#
# Inner Focus; Infiltrator; ; ; ; ; It does not need eyes, because it emits ultrasonic waves to check its surroundings while it flies.; Zubat; Golbat; Crobat; ; 1; 0.79m; 041; Zubat; Bat Pokemon; 45; 35; 40; 30; 40; 55; 245; Poison; Flying; 7.5 kg
#
# Inner Focus; Infiltrator; ; ; ; ; Flitting around in the dead of night, it sinks its fangs into its prey and drains a nearly fatal amount of blood.; Zubat; Golbat; Crobat; ; 1; 1.60m; 042; Golbat; Bat Pokemon; 80; 70; 75; 65; 75; 90; 455; Poison; Flying; 55.0 kg
#
# Chlorophyll; Run Away; ; ; ; ; It often plants its root feet in the ground during the day and sows seeds as it walks about at night.; Oddish; Gloom; Vileplume; ; 1; 0.51m; 043; Oddish; Weed Pokemon; 50; 55; 45; 75; 65; 30; 320; Grass; Poison; 5.4 kg
#
# Chlorophyll; Stench; ; ; ; ; The honey it drools from its mouth smells so atrocious, it can curl noses more than a mile away.; Oddish; Gloom; Vileplume; ; 1; 0.79m; 044; Gloom; Weed Pokemon; 65; 70; 60; 85; 75; 40; 395; Grass; Poison; 8.6 kg
#
# Chlorophyll; Effect Spore; ; ; ; ; Its petals are the largest in the world. As it walks, it scatters extremely allergenic pollen.; Oddish; Gloom; Vileplume; ; 1; 1.19m; 045; Vileplume; Flower Pokemon; 80; 85; 75; 110; 90; 50; 490; Grass; Poison; 18.6 kg
#
# Dry Skin; Effect Spore; Damp; ; ; ; Mushrooms named tochukaso grow on its back. They grow along with the host Paras.; Paras; Parasect; ; ; 1; 0.30m; 046; Paras; Mushroom Pokemon; 70; 55; 35; 45; 55; 25; 285; Bug; Grass; 5.4 kg
#
# Dry Skin; Effect Spore; Damp; ; ; ; A mushroom grown larger than the hosts body controls Parasect. It scatters poisonous spores.; Paras; Parasect; ; ; 1; 0.99m; 047; Parasect; Mushroom Pokemon; 95; 80; 60; 60; 80; 30; 405; Bug; Grass; 29.5 kg
#
# Compound Eyes; Tinted Lens; Run Away; ; ; ; Its big eyes are actually clusters of tiny eyes. At night, its kind is drawn by light.; Venonat; Venomoth; ; ; 1; 0.99m; 048; Venonat; Insect Pokemon; 55; 50; 60; 40; 55; 45; 305; Bug; Poison; 30.0 kg
#
# Shield Dust; Tinted Lens; Wonder Skin; ; ; ; It flutters its wings to scatter dustlike scales. The scales leach toxins if they contact skin.; Venonat; Venomoth; ; ; 1; 1.50m; 049; Venomoth; Poison Moth Pokemon; 65; 60; 70; 90; 75; 90; 450; Bug; Poison; 12.5 kg
#
# Arena Trap; Sand Veil; Sand Force; ; ; ; A Pokemon that lives underground. Because of its dark habitat, it is repelled by bright sunlight.; Diglett; Dugtrio; ; ; 1; 0.20m; 050; Diglett; Mole Pokemon; 55; 25; 10; 35; 45; 95; 265; Ground; ; 0.8 kg
#
# Arena Trap; Sand Veil; Sand Force; ; ; ; Its three heads move alternately, driving it through tough soil to depths of over 60 miles.; Diglett; Dugtrio; ; ; 1; 0.71m; 051; Dugtrio; Mole Pokemon; 80; 50; 35; 50; 70; 120; 405; Ground; ; 33.3 kg
#
# Pickup; Technician; Unnerve; ; ; ; It is nocturnal in nature. If it spots something shiny, its eyes glitter brightly.; Meowth; Persian; ; ; 1; 0.41m; 052; Meowth; Scratch Cat Pokemon; 45; 35; 40; 40; 40; 90; 290; Normal; ; 4.2 kg
#
# Limber; Technician; Unnerve; ; ; ; A very haughty Pokemon. Among fans, the size of the jewel in its forehead is a topic of much talk.; Meowth; Persian; ; ; 1; 0.99m; 053; Persian; Classy Cat Pokemon; 70; 60; 65; 65; 65; 115; 440; Normal; ; 32.0 kg
#
# Cloud Nine; Damp; Swift Swim; ; ; ; When headaches stimulate its brain cells, which are usually inactive, it can use a mysterious power.; Psyduck; Golduck; ; ; 1; 0.79m; 054; Psyduck; Duck Pokemon; 52; 48; 50; 65; 50; 55; 320; Water; ; 19.6 kg
#
# Cloud Nine; Damp; Swift Swim; ; ; ; When its forehead shines mysteriously, Golduck can use the full extent of its power.; Psyduck; Golduck; ; ; 1; 1.70m; 055; Golduck; Duck Pokemon; 82; 78; 80; 95; 80; 85; 500; Water; ; 76.6 kg
#
# Anger Point; Vital Spirit; Defiant; ; ; ; It lives in treetop colonies. If one becomes enraged, the whole colony rampages for no reason.; Mankey; Primeape; ; ; 1; 0.51m; 056; Mankey; Pig Monkey Pokemon; 80; 35; 40; 35; 45; 70; 305; Fighting; ; 28.0 kg
#
# Anger Point; Vital Spirit; Defiant; ; ; ; It grows angry if you see its eyes and gets angrier if you run. If you beat it, it gets even madder.; Mankey; Primeape; ; ; 1; 0.99m; 057; Primeape; Pig Monkey Pokemon; 105; 60; 65; 60; 70; 95; 455; Fighting; ; 32.0 kg
#
# Flash Fire; Intimidate; Justified; ; ; ; Extremely loyal to its Trainer, it will bark at those who approach the Trainer unexpectedly and run them out of town.; Growlithe; Arcanine; ; ; 1; 0.71m; 058; Growlithe; Puppy Pokemon; 70; 45; 55; 70; 50; 60; 350; Fire; ; 19.0 kg
#
# Flash Fire; Intimidate; Justified; ; ; ; The sight of it running over 6,200 miles in a single day and night has captivated many people.; Growlithe; Arcanine; ; ; 1; 1.91m; 059; Arcanine; Legendary Pokemon; 110; 80; 90; 100; 80; 95; 555; Fire; ; 155.0 kg
#
# Damp; Water Absorb; Swift Swim; ; ; ; Its skin is so thin, its internal organs are visible. It has trouble walking on its newly grown feet.; Poliwag; Poliwhirl; Poliwrath; ; 1; 0.61m; 060; Poliwag; Tadpole Pokemon; 50; 40; 40; 40; 40; 90; 300; Water; ; 12.4 kg
#
# Damp; Water Absorb; Swift Swim; ; ; ; The spiral pattern on its belly subtly undulates. Staring at it gradually causes drowsiness.; Poliwag; Poliwhirl; Poliwrath; ; 1; 0.99m; 061; Poliwhirl; Tadpole Pokemon; 65; 65; 65; 50; 50; 90; 385; Water; ; 20.0 kg
#
# Damp; Water Absorb; Swift Swim; ; ; ; With its extremely tough muscles, it can keep swimming in the Pacific Ocean without resting.; Poliwag; Poliwhirl; Poliwrath; ; 1; 1.30m; 062; Poliwrath; Tadpole Pokemon; 95; 95; 90; 70; 90; 70; 510; Water; Fighting; 54.0 kg
#
# Inner Focus; Synchronize; Magic Guard; ; ; ; Using its psychic power is such a strain on its brain that it needs to sleep for 18 hours a day.; Abra; Kadabra; Alakazam; ; 1; 0.89m; 063; Abra; Psi Pokemon; 20; 15; 25; 105; 55; 90; 310; Psychic; ; 19.5 kg
#
# Inner Focus; Synchronize; Magic Guard; ; ; ; It stares at its silver spoon to focus its mind. It emits more alpha waves while doing so.; Abra; Kadabra; Alakazam; ; 1; 1.30m; 064; Kadabra; Psi Pokemon; 35; 30; 40; 120; 70; 105; 400; Psychic; ; 56.5 kg
#
# Inner Focus; Synchronize; Magic Guard; ; ; ; The spoons clutched in its hands are said to have been created by its psychic powers.; Abra; Kadabra; Alakazam; ; 1; 1.50m; 065; Alakazam; Psi Pokemon; 50; 45; 55; 135; 95; 120; 500; Psychic; ; 48.0 kg
#
# Guts; No Guard; Steadfast; ; ; ; Though small in stature, it is powerful enough to easily heft and throw a number of Geodude at once.; Machop; Machoke; Machamp; ; 1; 0.79m; 066; Machop; Superpower Pokemon; 80; 50; 70; 35; 35; 35; 305; Fighting; ; 19.5 kg
#
# Guts; No Guard; Steadfast; ; ; ; It happily carries heavy cargo to toughen up. It willingly does hard work for people.; Machop; Machoke; Machamp; ; 1; 1.50m; 067; Machoke; Superpower Pokemon; 100; 70; 80; 50; 60; 45; 405; Fighting; ; 70.5 kg
#
# Guts; No Guard; Steadfast; ; ; ; Its four muscled arms slam foes with powerful punches and chops at blinding speed.; Machop; Machoke; Machamp; ; 1; 1.60m; 068; Machamp; Superpower Pokemon; 130; 80; 90; 65; 85; 55; 505; Fighting; ; 130.0 kg
#
# Chlorophyll; Gluttony; ; ; ; ; It prefers hot and humid environments. It is quick at capturing prey with its vines.; Bellsprout; Weepinbell; Victreebel; ; 1; 0.71m; 069; Bellsprout; Flower Pokemon; 75; 35; 50; 70; 30; 40; 300; Grass; Poison; 4.0 kg
#
# Chlorophyll; Gluttony; ; ; ; ; A Pokemon that appears to be a plant. It captures unwary prey by dousing them with a toxic powder.; Bellsprout; Weepinbell; Victreebel; ; 1; 0.99m; 070; Weepinbell; Flycatcher Pokemon; 90; 50; 65; 85; 45; 55; 390; Grass; Poison; 6.4 kg
#
# Chlorophyll; Gluttony; ; ; ; ; It pools in its mouth a fluid with a honey-like scent, which is really an acid that dissolves anything.; Bellsprout; Weepinbell; Victreebel; ; 1; 1.70m; 071; Victreebel; Flycatcher Pokemon; 105; 65; 80; 100; 70; 70; 490; Grass; Poison; 15.5 kg
#
# Clear Body; Liquid Ooze; Rain Dish; ; ; ; Because its body is almost entirely composed of water, it shrivels up if it is washed ashore.; Tentacool; Tentacruel; ; ; 1; 0.89m; 072; Tentacool; Jellyfish Pokemon; 40; 35; 40; 50; 100; 70; 335; Water; Poison; 45.5 kg
#
# Clear Body; Liquid Ooze; Rain Dish; ; ; ; It extends its 80 tentacles to form an encircling poisonous net that is difficult to escape.; Tentacool; Tentacruel; ; ; 1; 1.60m; 073; Tentacruel; Jellyfish Pokemon; 70; 65; 80; 80; 120; 100; 515; Water; Poison; 55.0 kg
#
# Rock Head; Sturdy; Sand Veil; ; ; ; At rest, it looks just like a rock. Carelessly stepping on it will make it swing its fists angrily.; Geodude; Graveler; Golem; ; 1; 0.41m; 074; Geodude; Rock Pokemon; 80; 100; 40; 30; 30; 20; 300; Rock; Ground; 20.0 kg
#
# Rock Head; Sturdy; Sand Veil; ; ; ; It rolls on mountain paths to move. Once it builds momentum, no Pokemon can stop it without difficulty.; Geodude; Graveler; Golem; ; 1; 0.99m; 075; Graveler; Rock Pokemon; 95; 115; 55; 45; 45; 35; 390; Rock; Ground; 105.0 kg
#
# Rock Head; Sturdy; Sand Veil; ; ; ; Even dynamite cant harm its hard, boulder-like body. It sheds its hide just once a year.; Geodude; Graveler; Golem; ; 1; 1.40m; 076; Golem; Megaton Pokemon; 120; 130; 80; 55; 65; 45; 495; Rock; Ground; 300.0 kg
#
# Flash Fire; Run Away; Flame Body; ; ; ; As a newborn, it can barely stand. However, through galloping, its legs are made tougher and faster.; Ponyta; Rapidash; ; ; 1; 0.99m; 077; Ponyta; Fire Horse Pokemon; 85; 55; 50; 65; 65; 90; 410; Fire; ; 30.0 kg
#
# Flash Fire; Run Away; Flame Body; ; ; ; When at an all-out gallop, its blazing mane sparkles, enhancing its beautiful appearance.; Ponyta; Rapidash; ; ; 1; 1.70m; 078; Rapidash; Fire Horse Pokemon; 100; 70; 65; 80; 80; 105; 500; Fire; ; 95.0 kg
#
# Oblivious; Own Tempo; Regenerator; ; ; ; Although slow, it is skilled at fishing with its tail. It does not feel pain if its tail is bitten.; Slowpoke; Slowbro; ; ; 1; 1.19m; 079; Slowpoke; Dopey Pokemon; 65; 65; 90; 40; 40; 15; 315; Water; Psychic; 36.0 kg
#
# Oblivious; Own Tempo; Regenerator; ; ; ; Though usually dim witted, it seems to become inspired if the Shellder on its tail bites down.; Slowpoke; Slowbro; ; ; 1; 1.60m; 080; Slowbro; Hermit Crab Pokemon; 75; 110; 95; 100; 80; 30; 490; Water; Psychic; 78.5 kg
#
# Magnet Pull; Sturdy; Analytic; ; ; ; The electromagnetic waves emitted by the units at the sides of its head expel antigravity, which allows it to float.; Magnemite; Magneton; ; ; 1; 0.30m; 081; Magnemite; Magnet Pokemon; 35; 70; 25; 95; 55; 45; 325; Electric; Steel; 6.0 kg
#
# Magnet Pull; Sturdy; Analytic; ; ; ; The stronger electromagnetic waves from the three linked Magnemite are enough to dry out surrounding moisture.; Magnemite; Magneton; ; ; 1; 0.99m; 082; Magneton; Magnet Pokemon; 60; 95; 50; 120; 70; 70; 465; Electric; Steel; 60.0 kg
#
# Inner Focus; Keen Eye; Defiant; ; ; ; It cant live without the stalk it holds. Thats why it defends the stalk from attackers with its life.; ; ; ; ; 1; 0.79m; 083; Farfetch'd; Wild Duck Pokemon; 65; 55; 52; 58; 62; 60; 352; Normal; Flying; 15.0 kg
#
# Early Bird; Run Away; Tangled Feet; ; ; ; The brains in its two heads appear to communicate emotions to each other with a telepathic power.; Doduo; Dodrio; ; ; 1; 1.40m; 084; Doduo; Twin Bird Pokemon; 85; 45; 35; 35; 35; 75; 310; Normal; Flying; 39.2 kg
#
# Early Bird; Run Away; Tangled Feet; ; ; ; When Doduo evolves into this odd breed, one of its heads splits into two. It runs at nearly 40 mph.; Doduo; Dodrio; ; ; 1; 1.80m; 085; Dodrio; Triple Bird Pokemon; 110; 70; 60; 60; 60; 100; 460; Normal; Flying; 85.2 kg
#
# Hydration; Thick Fat; Ice Body; ; ; ; The colder it gets, the better it feels. It joyfully swims around oceans so cold that they are filled with floating ice.; Seel; Dewgong; ; ; 1; 1.09m; 086; Seel; Sea Lion Pokemon; 45; 55; 65; 45; 70; 45; 325; Water; ; 90.0 kg
#
# Hydration; Thick Fat; Ice Body; ; ; ; Its streamlined body has low resistance, and it swims around cold oceans at a speed of eight knots.; Seel; Dewgong; ; ; 1; 1.70m; 087; Dewgong; Sea Lion Pokemon; 70; 80; 90; 70; 95; 70; 475; Water; Ice; 120.0 kg
#
# Stench; Sticky Hold; Poison Touch; ; ; ; Born from sludge, these Pokemon now gather in polluted places and increase the bacteria in their bodies.; Grimer; Muk; ; ; 1; 0.89m; 088; Grimer; Sludge Pokemon; 80; 50; 80; 40; 50; 25; 325; Poison; ; 30.0 kg
#
# Stench; Sticky Hold; Poison Touch; ; ; ; Its so stinky! Muks body contains toxic elements, and any plant will wilt when it passes by.; Grimer; Muk; ; ; 1; 1.19m; 089; Muk; Sludge Pokemon; 105; 75; 105; 65; 100; 50; 500; Poison; ; 30.0 kg
#
# Shell Armor; Skill Link; Overcoat; ; ; ; It swims backward by opening and closing its two shells. Its large tongue is always kept hanging out.; Shellder; Cloyster; ; ; 1; 0.30m; 090; Shellder; Bivalve Pokemon; 65; 100; 30; 45; 25; 40; 305; Water; ; 4.0 kg
#
# Shell Armor; Skill Link; Overcoat; ; ; ; It fights by keeping its shell tightly shut for protection and by shooting spikes to repel foes.; Shellder; Cloyster; ; ; 1; 1.50m; 091; Cloyster; Bivalve Pokemon; 95; 180; 50; 85; 45; 70; 525; Water; Ice; 132.5 kg
#
# Levitate; ; ; ; ; ; Born from gases, anyone would faint if engulfed by its gaseous body, which contains poison.; Gastly; Haunter; Gengar; ; 1; 1.30m; 092; Gastly; Gas Pokemon; 35; 30; 30; 100; 35; 80; 310; Ghost; Poison; 0.1 kg
#
# Levitate; ; ; ; ; ; It likes to lurk in the dark and tap shoulders with a gaseous hand. Its touch causes endless shuddering.; Gastly; Haunter; Gengar; ; 1; 1.60m; 093; Haunter; Gas Pokemon; 50; 45; 45; 115; 55; 95; 405; Ghost; Poison; 0.1 kg
#
# Levitate; ; ; ; ; ; The leer that floats in darkness belongs to a Gengar delighting in casting curses on people.; Gastly; Haunter; Gengar; ; 1; 1.50m; 094; Gengar; Shadow Pokemon; 65; 60; 60; 130; 75; 110; 500; Ghost; Poison; 40.5 kg
#
# Rock Head; Sturdy; Weak Armor; ; ; ; Opening its large mouth, it ingests massive amounts of soil and creates long tunnels.; Onix; ; ; ; 1; 8.79m; 095; Onix; Rock Snake Pokemon; 45; 160; 35; 30; 45; 70; 385; Rock; Ground; 210.0 kg
#
# Forewarn; Insomnia; Inner Focus; ; ; ; It can tell what people are dreaming by sniffing with its big nose. It loves fun dreams.; Drowzee; Hypno; ; ; 1; 0.99m; 096; Drowzee; Hypnosis Pokemon; 48; 45; 60; 43; 90; 42; 328; Psychic; ; 32.4 kg
#
# Forewarn; Insomnia; Inner Focus; ; ; ; Seeing its swinging pendulum can induce sleep in three seconds, even in someone who just woke up.; Drowzee; Hypno; ; ; 1; 1.60m; 097; Hypno; Hypnosis Pokemon; 73; 70; 85; 73; 115; 67; 483; Psychic; ; 75.6 kg
#
# Hyper Cutter; Shell Armor; Sheer Force; ; ; ; It lives in burrows dug on sandy beaches. Its pincers fully grow back if they are broken in battle.; Krabby; Kingler; ; ; 1; 0.41m; 098; Krabby; River Crab Pokemon; 105; 90; 30; 25; 25; 50; 325; Water; ; 6.5 kg
#
# Hyper Cutter; Shell Armor; Sheer Force; ; ; ; The larger pincer has 10,000- horsepower strength. However, it is so heavy, it is difficult to aim.; Krabby; Kingler; ; ; 1; 1.30m; 099; Kingler; Pincer Pokemon; 130; 115; 55; 50; 50; 75; 475; Water; ; 60.0 kg
#
# Soundproof; Static; Aftermath; ; ; ; It looks just like a Pok Ball. It is dangerous because it may electrocute or explode on contact.; Voltorb; Electrode; ; ; 1; 0.51m; 100; Voltorb; Ball Pokemon; 30; 50; 40; 55; 55; 100; 330; Electric; ; 10.4 kg
#
# Soundproof; Static; Aftermath; ; ; ; It is known to drift on winds if it is bloated to bursting with stored electricity.; Voltorb; Electrode; ; ; 1; 1.19m; 101; Electrode; Ball Pokemon; 50; 70; 60; 80; 80; 140; 480; Electric; ; 66.6 kg
#
# Chlorophyll; Harvest; ; ; ; ; Its six eggs converse using telepathy. They can quickly gather if they become separated.; Exeggcute; Exeggutor; ; ; 1; 0.41m; 102; Exeggcute; Egg Pokemon; 40; 80; 60; 60; 45; 40; 325; Grass; Psychic; 2.5 kg
#
# Chlorophyll; Harvest; ; ; ; ; It is called The Walking Jungle. If a head grows too big, it falls off and becomes an Exeggcute.; Exeggcute; Exeggutor; ; ; 1; 2.01m; 103; Exeggutor; Coconut Pokemon; 95; 85; 95; 125; 65; 55; 520; Grass; Psychic; 120.0 kg
#
# Lightning Rod; Rock Head; Battle Armor; ; ; ; When it thinks of its dead mother, it cries. Its crying makes the skull it wears rattle hollowly.; Cubone; Marowak; ; ; 1; 0.41m; 104; Cubone; Lonely Pokemon; 50; 95; 50; 40; 50; 35; 320; Ground; ; 6.5 kg
#
# Lightning Rod; Rock Head; Battle Armor; ; ; ; From its birth, this savage Pokemon constantly holds bones. It is skilled in using them as weapons.; Cubone; Marowak; ; ; 1; 0.99m; 105; Marowak; Bone Keeper Pokemon; 80; 110; 60; 50; 80; 45; 425; Ground; ; 45.0 kg
#
# Limber; Reckless; Unburden; ; ; ; Its legs can stretch double. First-time foes are startled by its extensible reach.; Hitmonlee; Hitmonchan; ; ; 1; 1.50m; 106; Hitmonlee; Kicking Pokemon; 120; 53; 50; 35; 110; 87; 455; Fighting; ; 49.8 kg
#
# Iron Fist; Keen Eye; Inner Focus; ; ; ; The arm-twisting punches it throws pulverize even concrete. It rests after three minutes of fighting.; Hitmonlee; Hitmonchan; ; ; 1; 1.40m; 107; Hitmonchan; Punching Pokemon; 105; 79; 50; 35; 110; 76; 455; Fighting; ; 50.2 kg
#
# Oblivious; Own Tempo; Cloud Nine; ; ; ; Being licked by its long, saliva-covered tongue leaves a tingling sensation. Extending its tongue retracts its tail.; Lickitung; ; ; ; 1; 1.19m; 108; Lickitung; Licking Pokemon; 55; 75; 90; 60; 75; 30; 385; Normal; ; 65.5 kg
#
# Levitate; ; ; ; ; ; Toxic gas is held within its thin, balloon-shaped body, so it can cause massive explosions.; Koffing; Weezing; ; ; 1; 0.61m; 109; Koffing; Poison Gas Pokemon; 65; 95; 40; 60; 45; 35; 340; Poison; ; 1.0 kg
#
# Levitate; ; ; ; ; ; Inhaling toxic fumes from trash and mixing them inside its body lets it spread an even fouler stench.; Koffing; Weezing; ; ; 1; 1.19m; 110; Weezing; Poison Gas Pokemon; 90; 120; 65; 85; 70; 60; 490; Poison; ; 9.5 kg
#
# Lightning Rod; Rock Head; Reckless; ; ; ; Its powerful tackles can destroy anything. However, it is too slow witted to help people work.; Rhyhorn; Rhydon; ; ; 1; 0.99m; 111; Rhyhorn; Spikes Pokemon; 85; 95; 80; 30; 30; 25; 345; Ground; Rock; 115.0 kg
#
# Lightning Rod; Rock Head; Reckless; ; ; ; Standing on its hind legs freed its forelegs and made it smarter. It is very forgetful, however.; Rhyhorn; Rhydon; ; ; 1; 1.91m; 112; Rhydon; Drill Pokemon; 130; 120; 105; 45; 45; 40; 485; Ground; Rock; 120.0 kg
#
# Natural Cure; Serene Grace; Healer; ; ; ; A kindly Pokemon that lays highly nutritious eggs and shares them with injured Pokmon or people.; Chansey; ; ; ; 1; 1.09m; 113; Chansey; Egg Pokemon; 5; 5; 250; 35; 105; 50; 450; Normal; ; 34.6 kg
#
# Chlorophyll; Leaf Guard; Regenerator; ; ; ; Many writhing vines cover it, so its true identity remains unknown. The blue vines grow its whole life long.; Tangela; ; ; ; 1; 0.99m; 114; Tangela; Vine Pokemon; 55; 115; 65; 100; 40; 60; 435; Grass; ; 35.0 kg
#
# Early Bird; Scrappy; Inner Focus; ; ; ; It raises its offspring in its belly pouch. It lets the baby out to play only when it feels safe.; ; ; ; ; 1; 2.21m; 115; Kangaskhan; Parent Pokemon; 95; 80; 105; 40; 80; 90; 490; Normal; ; 80.0 kg
#
# Sniper; Swift Swim; Damp; ; ; ; It makes its nest in the shade of corals. If it senses danger, it spits murky ink and flees.; Horsea; Seadra; ; ; 1; 0.41m; 116; Horsea; Dragon Pokemon; 40; 70; 30; 70; 25; 60; 295; Water; ; 8.0 kg
#
# Poison Point; Sniper; Damp; ; ; ; Its spines provide protection. Its fins and bones are prized as traditional-medicine ingredients.; Horsea; Seadra; ; ; 1; 1.19m; 117; Seadra; Dragon Pokemon; 65; 95; 55; 95; 45; 85; 440; Water; ; 25.0 kg
#
# Swift Swim; Water Veil; Lightning Rod; ; ; ; Though it appears very elegant when swimming with fins unfurled, it can jab powerfully with its horn.; Goldeen; Seaking; ; ; 1; 0.61m; 118; Goldeen; Goldfish Pokemon; 67; 60; 45; 35; 50; 63; 320; Water; ; 15.0 kg
#
# Swift Swim; Water Veil; Lightning Rod; ; ; ; In autumn, its body becomes more fatty in preparing to propose to a mate. It takes on beautiful colors.; Goldeen; Seaking; ; ; 1; 1.30m; 119; Seaking; Goldfish Pokemon; 92; 65; 80; 65; 80; 68; 450; Water; ; 39.0 kg
#
# Illuminate; Natural Cure; Analytic; ; ; ; As long as its red core remains, it can regenerate its body instantly, even if its torn apart.; Staryu; Starmie; ; ; 1; 0.79m; 120; Staryu; Star Shape Pokemon; 45; 55; 30; 70; 55; 85; 340; Water; ; 34.5 kg
#
# Illuminate; Natural Cure; Analytic; ; ; ; Its core shines in many colors and sends radio signals into space to communicate with something.; Staryu; Starmie; ; ; 1; 1.09m; 121; Starmie; Mysterious Pokemon; 75; 85; 60; 100; 85; 115; 520; Water; Psychic; 80.0 kg
#
# Filter; Soundproof; Technician; ; ; ; It shapes an invisible wall in midair by minutely vibrating its fingertips to stop molecules in the air.; Mr. Mime; ; ; ; 1; 1.30m; 122; Mr. Mime; Barrier Pokemon; 45; 65; 40; 100; 120; 90; 460; Psychic; Fairy; 54.5 kg
#
# Swarm; Technician; Steadfast; ; ; ; The sharp scythes on its forearms become increasingly sharp by cutting through hard objects.; Scyther; ; ; ; 1; 1.50m; 123; Scyther; Mantis Pokemon; 110; 80; 70; 55; 80; 105; 500; Bug; Flying; 56.0 kg
#
# Forewarn; Oblivious; Dry Skin; ; ; ; Its cries sound like human speech. However, it is impossible to tell what it is trying to say.; Jynx; ; ; ; 1; 1.40m; 124; Jynx; Human Shape Pokemon; 50; 35; 65; 115; 95; 95; 455; Ice; Psychic; 40.6 kg
#
# Static; Vital Spirit; ; ; ; ; Research is progressing on storing lightning in Electabuzz so this energy can be used at any time.; Electabuzz; ; ; ; 1; 1.09m; 125; Electabuzz; Electric Pokemon; 83; 57; 65; 95; 85; 105; 490; Electric; ; 30.0 kg
#
# Flame Body; Vital Spirit; ; ; ; ; The scorching fire exhaled by Magmar forms heat waves around its body, making it hard to see the Pokemon clearly.; Magmar; ; ; ; 1; 1.30m; 126; Magmar; Spitfire Pokemon; 95; 57; 65; 100; 85; 93; 495; Fire; ; 44.5 kg
#
# Hyper Cutter; Mold Breaker; Moxie; ; ; ; It grips prey with its powerful pincers and will not let go until the prey is torn in half.; ; ; ; ; 1; 1.50m; 127; Pinsir; Stag Beetle Pokemon; 125; 100; 65; 55; 70; 85; 500; Bug; ; 55.0 kg
#
# Anger Point; Intimidate; Sheer Force; ; ; ; Once it takes aim at its foe, it makes a headlong charge. It is famous for its violent nature.; ; ; ; ; 1; 1.40m; 128; Tauros; Wild Bull Pokemon; 100; 95; 75; 40; 70; 110; 490; Normal; ; 88.4 kg
#
# Swift Swim; Rattled; ; ; ; ; A Magikarp living for many years can leap a mountain using Splash. The move remains useless, though.; Magikarp; Gyarados; ; ; 1; 0.89m; 129; Magikarp; Fish Pokemon; 10; 55; 20; 15; 20; 80; 200; Water; ; 10.0 kg
#
# Intimidate; Moxie; ; ; ; ; Once it begins to rampage, a Gyarados will burn everything down, even in a harsh storm.; Magikarp; Gyarados; ; ; 1; 6.50m; 130; Gyarados; Atrocious Pokemon; 125; 79; 95; 60; 100; 81; 540; Water; Flying; 235.0 kg
#
# Shell Armor; Water Absorb; Hydration; ; ; ; Able to understand human speech and very intelligent, it loves to swim in the sea with people on its back.; ; ; ; ; 1; 2.49m; 131; Lapras; Transport Pokemon; 85; 80; 130; 85; 95; 60; 535; Water; Ice; 220.0 kg
#
# Limber; Imposter; ; ; ; ; It can reconstitute its entire cellular structure to change into what it sees, but it returns to normal when it relaxes.; ; ; ; ; 1; 0.30m; 132; Ditto; Transform Pokemon; 48; 48; 48; 48; 48; 48; 288; Normal; ; 4.0 kg
#
# Adaptability; Run Away; Anticipation; ; ; ; Thanks to its unstable genetic makeup, this special Pokemon conceals many different possible evolutions.; Vaporeon; Jolteon; Flareon; Eevee; 1; 0.30m; 133; Eevee; Evolution Pokemon; 55; 50; 55; 45; 65; 55; 325; Normal; ; 6.5 kg
#
# Water Absorb; Hydration; ; ; ; ; Its cell composition is similar to water molecules. As a result, it cant be seen when it melts away into water.; Vaporeon; Jolteon; Flareon; Eevee; 1; 0.99m; 134; Vaporeon; Bubble Jet Pokemon; 65; 60; 130; 110; 95; 65; 525; Water; ; 29.0 kg
#
# Volt Absorb; Quick Feet; ; ; ; ; By storing electricity in its body, it can shoot its bristlelike fur like a barrage of missiles.; Vaporeon; Jolteon; Flareon; Eevee; 1; 0.79m; 135; Jolteon; Lightning Pokemon; 65; 60; 65; 110; 95; 130; 525; Electric; ; 24.5 kg
#
# Flash Fire; Guts; ; ; ; ; Inhaled air is carried to its flame sac, heated, and exhaled as fire that reaches over 3,000 degrees F.; Vaporeon; Jolteon; Flareon; Eevee; 1; 0.89m; 136; Flareon; Flame Pokemon; 130; 60; 65; 95; 110; 65; 525; Fire; ; 25.0 kg
#
# Download; Trace; Analytic; ; ; ; A man-made Pokemon created using advanced scientific means. It can move freely in cyberspace.; Porygon; ; ; ; 1; 0.79m; 137; Porygon; Virtual Pokemon; 60; 70; 65; 85; 75; 40; 395; Normal; ; 36.5 kg
#
# Shell Armor; Swift Swim; Weak Armor; ; ; ; A Pokemon that was resurrected from a fossil using modern science. It swam in ancient seas.; Omanyte; Omastar; ; ; 1; 0.41m; 138; Omanyte; Spiral Pokemon; 40; 100; 35; 90; 55; 35; 355; Rock; Water; 7.5 kg
#
# Shell Armor; Swift Swim; Weak Armor; ; ; ; It is thought that this Pokemon became extinct because its spiral shell grew too large.; Omanyte; Omastar; ; ; 1; 0.99m; 139; Omastar; Spiral Pokemon; 60; 125; 70; 115; 70; 55; 495; Rock; Water; 35.0 kg
#
# Battle Armor; Swift Swim; Weak Armor; ; ; ; It is thought to have inhabited beaches 300 million years ago. It is protected by a stiff shell.; Kabuto; Kabutops; ; ; 1; 0.51m; 140; Kabuto; Shellfish Pokemon; 80; 90; 30; 55; 45; 55; 355; Rock; Water; 11.5 kg
#
# Battle Armor; Swift Swim; Weak Armor; ; ; ; It is thought that this Pokemon came onto land because its prey adapted to life on land.; Kabuto; Kabutops; ; ; 1; 1.30m; 141; Kabutops; Shellfish Pokemon; 115; 105; 60; 65; 70; 80; 495; Rock; Water; 40.5 kg
#
# Pressure; Rock Head; Unnerve; ; ; ; A Pokemon that roamed the skies in the dinosaur era. Its teeth are like saw blades.; ; ; ; ; 1; 1.80m; 142; Aerodactyl; Fossil Pokemon; 105; 65; 80; 60; 75; 130; 515; Rock; Flying; 59.0 kg
#
# Immunity; Thick Fat; Gluttony; ; ; ; When its belly is full, it becomes too lethargic to even lift a finger, so it is safe to bounce on its belly.; Snorlax; ; ; ; 1; 2.11m; 143; Snorlax; Sleeping Pokemon; 110; 65; 160; 65; 110; 30; 540; Normal; ; 460.0 kg
#
# Pressure; Snow Cloak; ; ; ; ; A legendary bird Pokemon. It can create blizzards by freezing moisture in the air.; ; ; ; ; 1; 1.70m; 144; Articuno; Freeze Pokemon; 85; 100; 90; 95; 125; 85; 580; Ice; Flying; 55.4 kg
#
# Pressure; Lightning Rod; ; ; ; ; A legendary Pokemon that is said to live in thunderclouds. It freely controls lightning bolts.; ; ; ; ; 1; 1.60m; 145; Zapdos; Electric Pokemon; 90; 85; 90; 125; 90; 100; 580; Electric; Flying; 52.6 kg
#
# Pressure; Flame Body; ; ; ; ; One of the legendary bird Pokemon. It is said that its appearance indicates the coming of spring.; ; ; ; ; 1; 2.01m; 146; Moltres; Flame Pokemon; 100; 90; 90; 125; 85; 90; 580; Fire; Flying; 60.0 kg
#
# Shed Skin; Marvel Scale; ; ; ; ; It is called the Mirage Pokemon because so few have seen it. Its shed skin has been found.; Dratini; Dragonair; Dragonite; ; 1; 1.80m; 147; Dratini; Dragon Pokemon; 64; 45; 41; 50; 50; 50; 300; Dragon; ; 3.3 kg
#
# Shed Skin; Marvel Scale; ; ; ; ; If its body takes on an aura, the weather changes instantly. It is said to live in seas and lakes.; Dratini; Dragonair; Dragonite; ; 1; 3.99m; 148; Dragonair; Dragon Pokemon; 84; 65; 61; 70; 70; 70; 420; Dragon; ; 16.5 kg
#
# Inner Focus; Multiscale; ; ; ; ; It is said to make its home somewhere in the sea. It guides crews of shipwrecks to shore.; Dratini; Dragonair; Dragonite; ; 1; 2.21m; 149; Dragonite; Dragon Pokemon; 134; 95; 91; 100; 100; 80; 600; Dragon; Flying; 210.0 kg
#
# Pressure; Unnerve; ; ; ; ; A Pokemon created by recombining Mews genes. Its said to have the most savage heart among Pokmon.; ; ; ; ; 1; 2.01m; 150; Mewtwo; Genetic Pokemon; 110; 90; 106; 154; 90; 130; 680; Psychic; ; 122.0 kg
#
# Synchronize; ; ; ; ; ; Mew is said to possess the genetic composition of all Pokemon. It is capable of making itself invisible at will, so it entirely avoids notice even if it approaches people.; ; ; ; ; 1; 0.41m; 151; Mew; New Species Pokemon; 100; 100; 100; 100; 100; 100; 600; Psychic; ; 4.0 kg
#
# Overgrow; Leaf Guard; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.9m; 152; Chikorita; Leaf Pokemon; 49; 65; 45; 49; 65; 45; 318; Grass; ; 6.4 kg
#
# Overgrow; Leaf Guard; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.2m; 153; Bayleef; Leaf Pokemon; 62; 80; 60; 63; 80; 60; 405; Grass; ; 15.8 kg
#
# Overgrow; Leaf Guard; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.8m; 154; Meganium; Herb Pokemon; 82; 100; 80; 83; 100; 80; 525; Grass; ; 100.5 kg
#
# Blaze; Flash Fire; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 155; Cyndaquil; Fire Mouse Pokemon; 52; 43; 39; 60; 50; 65; 309; Fire; ; 7.9 kg
#
# Blaze; Flash Fire; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.9m; 156; Quilava; Volcano Pokemon; 64; 58; 58; 80; 65; 80; 405; Fire; ;
#
# Blaze; Flash Fire; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.7m; 157; Typhlosion; Volcano Pokemon; 84; 78; 78; 109; 85; 100; 534; Fire; ; 79.5 kg
#
# Torrent; Sheer Force; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 158; Totodile; Big Jaw Pokemon; 65; 64; 50; 44; 48; 43; 314; Water; ; 9.5 kg
#
# Torrent; Sheer Force; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.1m; 159; Croconaw; Big Jaw Pokemon; 80; 80; 65; 59; 63; 58; 405; Water; ;
#
# Torrent; Sheer Force; ; ; ; ; Description not available yet; ; ; ; ; 2; 2.3m; 160; Feraligatr; Big Jaw Pokemon; 105; 100; 85; 79; 83; 78; 530; Water; ; 88.8 kg
#
# Run Away; Keen Eye; Frisk; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 161; Sentret; Scout Pokemon; 46; 34; 35; 35; 45; 20; 215; Normal; ;
#
# Run Away; Keen Eye; Frisk; ; ; ; Description not available yet; ; ; ; ; 2; 1.8m; 162; Furret; Long Body Pokemon; 76; 64; 85; 45; 55; 90; 415; Normal; ; 32.5 kg
#
# Insomnia; Keen Eye; Tinted Lens; ; ; ; Description not available yet; ; ; ; ; 2; 0.7m; 163; Hoothoot; Owl Pokemon; 30; 30; 60; 36; 56; 50; 262; Normal; Flying; 21.2 kg
#
# Insomnia; Keen Eye; Tinted Lens; ; ; ; Description not available yet; ; ; ; ; 2; 1.6m; 164; Noctowl; Owl Pokemon; 50; 50; 100; 86; 96; 70; 452; Normal; Flying; 40.8 kg
#
# Swarm; Early Bird; Rattled; ; ; ; Description not available yet; ; ; ; ; 2; ; 165; Ledyba; Five Star Pokemon; 20; 30; 40; 40; 80; 55; 265; Bug; Flying; 10.8 kg
#
# Swarm; Early Bird; Iron Fist; ; ; ; Description not available yet; ; ; ; ; 2; 1.4m; 166; Ledian; Five Star Pokemon; 35; 50; 55; 55; 110; 85; 390; Bug; Flying; 35.6 kg
#
# Swarm; Insomnia; Sniper; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 167; Spinarak; String Spit Pokemon; 60; 40; 40; 40; 40; 30; 250; Bug; Poison; 8.5 kg
#
# Swarm; Insomnia; Sniper; ; ; ; Description not available yet; ; ; ; ; 2; 1.1m; 168; Ariados; Long Leg Pokemon; 90; 70; 70; 60; 70; 40; 400; Bug; Poison; 33.5 kg
#
# Inner Focus; Infiltrator; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.8m; 169; Crobat; Bat Pokemon; 90; 80; 85; 70; 80; 130; 535; Poison; Flying;
#
# Volt Absorb; Illuminate; Water Absorb; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 170; Chinchou; Angler Pokemon; 38; 38; 75; 56; 56; 67; 330; Water; Electric;
#
# Volt Absorb; Illuminate; Water Absorb; ; ; ; Description not available yet; ; ; ; ; 2; 1.2m; 171; Lanturn; Light Pokemon; 58; 58; 125; 76; 76; 67; 460; Water; Electric; 22.5 kg
#
# Static; Lightningrod; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.3m; 172; Pichu; Tiny Mouse Pokemon; 40; 15; 20; 35; 35; 60; 205; Electric; ;
#
# Cute Charm; Magic Guard; Friend Guard; ; ; ; Description not available yet; ; ; ; ; 2; 0.3m; 173; Cleffa; Star Shape Pokemon; 25; 28; 50; 45; 55; 15; 218; Fairy; ;
#
# Cute Charm; Competitive; Friend Guard; ; ; ; Description not available yet; ; ; ; ; 2; 0.3m; 174; Igglybuff; Balloon Pokemon; 30; 15; 90; 40; 20; 15; 210; Normal; Fairy;
#
# Hustle; Serene Grace; Super Luck; ; ; ; Description not available yet; ; ; ; ; 2; 0.3m; 175; Togepi; Spike Ball Pokemon; 20; 65; 35; 40; 65; 20; 245; Fairy; ; 1.5 kg
#
# Hustle; Serene Grace; Super Luck; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 176; Togetic; Happiness Pokemon; 40; 85; 55; 80; 105; 40; 405; Fairy; Flying; 3.2 kg
#
# Synchronize; Early Bird; Magic Bounce; ; ; ; Description not available yet; ; ; ; ; 2; 0.2m; 177; Natu; Little Bird Pokemon; 50; 45; 40; 70; 45; 70; 320; Psychic; Flying;
#
# Synchronize; Early Bird; Magic Bounce; ; ; ; Description not available yet; ; ; ; ; 2; 1.5m; 178; Xatu; Mystic Pokemon; 75; 70; 65; 95; 70; 95; 470; Psychic; Flying;
#
# Static; Plus; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 179; Mareep; Wool Pokemon; 40; 40; 55; 65; 45; 35; 280; Electric; ; 7.8 kg
#
# Static; Plus; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 180; Flaaffy; Wool Pokemon; 55; 55; 70; 80; 60; 45; 365; Electric; ; 13.3 kg
#
# Static; Plus; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.4m; 181; Ampharos; Light Pokemon; 95; 105; 90; 165; 110; 45; 610; Electric; ; 61.5 kg
#
# Chlorophyll; Healer; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.4m; 182; Bellossom; Flower Pokemon; 80; 95; 75; 90; 100; 50; 490; Grass; ; 5.8 kg
#
# Thick Fat; Huge Power; Sap Sipper; ; ; ; Description not available yet; ; ; ; ; 2; 0.4m; 183; Marill; Aquamouse Pokemon; 20; 50; 70; 20; 50; 40; 250; Water; Fairy; 8.5 kg
#
# Thick Fat; Huge Power; Sap Sipper; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 184; Azumarill; Aquarabbit Pokemon; 50; 80; 100; 60; 80; 50; 420; Water; Fairy; 28.5 kg
#
# Sturdy; Rock Head; Rattled; ; ; ; Description not available yet; ; ; ; ; 2; 1.2m; 185; Sudowoodo; Imitation Pokemon; 100; 115; 70; 30; 65; 30; 410; Rock; ;
#
# Water Absorb; Damp; Drizzle; ; ; ; Description not available yet; ; ; ; ; 2; 1.1m; 186; Politoed; Frog Pokemon; 75; 75; 90; 90; 100; 70; 500; Water; ; 33.9 kg
#
# Chlorophyll; Leaf Guard; Infiltrator; ; ; ; Description not available yet; ; ; ; ; 2; 0.4m; 187; Hoppip; Cottonweed Pokemon; 35; 40; 35; 35; 55; 50; 250; Grass; Flying; 0.5 kg
#
# Chlorophyll; Leaf Guard; Infiltrator; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 188; Skiploom; Cottonweed Pokemon; 45; 50; 55; 45; 65; 80; 340; Grass; Flying;
#
# Chlorophyll; Leaf Guard; Infiltrator; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 189; Jumpluff; Cottonweed Pokemon; 55; 70; 75; 55; 95; 110; 460; Grass; Flying;
#
# Run Away; Pickup; Skill Link; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 190; Aipom; Long Tail Pokemon; 70; 55; 55; 40; 55; 85; 360; Normal; ; 11.5 kg
#
# Chlorophyll; Solar Power; Early Bird; ; ; ; Description not available yet; ; ; ; ; 2; 0.3m; 191; Sunkern; Seed Pokemon; 30; 30; 30; 30; 30; 30; 180; Grass; ; 1.8 kg
#
# Chlorophyll; Solar Power; Early Bird; ; ; ; Description not available yet; ; ; ; ; 2; 0.8m; 192; Sunflora; Sun Pokemon; 75; 55; 75; 105; 85; 30; 425; Grass; ; 8.5 kg
#
# Speed Boost; Compoundeyes; Frisk; ; ; ; Description not available yet; ; ; ; ; 2; 1.2m; 193; Yanma; Clear Wing Pokemon; 65; 45; 65; 75; 45; 95; 390; Bug; Flying;
#
# Damp; Water Absorb; Unaware; ; ; ; Description not available yet; ; ; ; ; 2; 0.4m; 194; Wooper; Water Fish Pokemon; 45; 45; 55; 25; 25; 15; 210; Water; Ground; 8.5 kg
#
# Damp; Water Absorb; Unaware; ; ; ; Description not available yet; ; ; ; ; 2; 1.4m; 195; Quagsire; Water Fish Pokemon; 85; 85; 95; 65; 65; 35; 430; Water; Ground;
#
# Synchronize; Magic Bounce; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.9m; 196; Espeon; Sun Pokemon; 65; 60; 65; 130; 95; 110; 525; Psychic; ; 26.5 kg
#
# Synchronize; Inner Focus; ; ; ; ; Description not available yet; ; ; ; ; 2; ; 197; Umbreon; Moonlight Pokemon; 65; 110; 95; 60; 130; 65; 525; Dark; ;
#
# Insomnia; Super Luck; Prankster; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 198; Murkrow; Darkness Pokemon; 85; 42; 60; 85; 42; 91; 405; Dark; Flying; 2.1 kg
#
# Oblivious; Own Tempo; Regenerator; ; ; ; Description not available yet; ; ; ; ; 2; ; 199; Slowking; Royal Pokemon; 75; 80; 95; 100; 110; 30; 490; Water; Psychic; 79.5 kg
#
# Levitate; ; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.7m; 200; Misdreavus; Screech Pokemon; 60; 60; 60; 85; 85; 85; 435; Ghost; ;
#
# Levitate; ; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 201; Unown; Symbol Pokemon; 72; 48; 48; 72; 48; 48; 336; Psychic; ;
#
# Shadow Tag; Telepathy; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.3m; 202; Wobbuffet; Patient Pokemon; 33; 58; 190; 33; 58; 33; 405; Psychic; ; 28.5 kg
#
# Inner Focus; Early Bird; Sap Sipper; ; ; ; Description not available yet; ; ; ; ; 2; 1.5m; 203; Girafarig; Long Neck Pokemon; 80; 65; 70; 90; 65; 85; 455; Normal; Psychic; 41.5 kg
#
# Sturdy; Overcoat; ; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 204; Pineco; Bagworm Pokemon; 65; 90; 50; 35; 35; 15; 290; Bug; ; 7.2 kg
#
# Sturdy; Overcoat; ; ; ; ; Description not available yet; ; ; ; ; 2; 1.2m; 205; Forretress; Bagworm Pokemon; 90; 140; 75; 60; 60; 40; 465; Bug; Steel; 125.8 kg
#
# Serene Grace; Run Away; Rattled; ; ; ; Description not available yet; ; ; ; ; 2; 1.5m; 206; Dunsparce; Land Snake Pokemon; 70; 70; 100; 65; 65; 45; 415; Normal; ;
#
# Hyper Cutter; Sand Veil; Immunity; ; ; ; Description not available yet; ; ; ; ; 2; 1.1m; 207; Gligar; Flyscorpion Pokemon; 75; 105; 65; 35; 65; 85; 430; Ground; Flying; 64.8 kg
#
# Rock Head; Sturdy; Sheer Force; ; ; ; Description not available yet; ; ; ; ; 2; 9.2m; 208; Steelix; Iron Snake Pokemon; 125; 230; 75; 55; 95; 30; 610; Steel; Ground;
#
# Intimidate; Run Away; Rattled; ; ; ; Description not available yet; ; ; ; ; 2; 0.6m; 209; Snubbull; Fairy Pokemon; 80; 50; 60; 40; 40; 30; 300; Fairy; ; 7.8 kg
#
# Intimidate; Quick Feet; Rattled; ; ; ; Description not available yet; ; ; ; ; 2; 1.4m; 210; Granbull; Fairy Pokemon; 120; 75; 90; 60; 60; 45; 450; Fairy; ; 48.7 kg
#
# Poison Point; Swift Swim; Intimidate; ; ; ; Description not available yet; ; ; ; ; 2; 0.5m; 211; Qwilfish; Balloon Pokemon; 95; 85; 65; 55; 55; 85; 440; Water; Poison; 3.9 kg
#
# ...
#
# Clear Body; Sturdy; ; ; ; ; Description not available yet; ; ; ; ; 6; 0.3m; 703; Carbink; Jewel Pokemon; 50; 150; 50; 50; 150; 50; 500; Rock; Fairy; 5.7 kg
#
# Sap Sipper; Hydration; Gooey; ; ; ; Description not available yet; ; ; ; ; 6; 0.3m; 704; Goomy; Soft Tissue Pokemon; 50; 35; 45; 55; 75; 40; 300; Dragon; ; 2.8 kg
#
# Sap Sipper; Hydration; Gooey; ; ; ; Description not available yet; ; ; ; ; 6; 0.8m; 705; Sliggoo; Soft Tissue Pokemon; 75; 53; 68; 83; 113; 60; 452; Dragon; ; 17.5 kg
#
# Sap Sipper; Hydration; Gooey; ; ; ; Description not available yet; ; ; ; ; 6; ; 706; Goodra; Dragon Pokemon; 100; 70; 90; 110; 150; 80; 600; Dragon; ; 150.5 kg
#
# Prankster; Magician; ; ; ; ; Description not available yet; ; ; ; ; 6; 0.2m; 707; Klefki; Key Ring Pokemon; 80; 91; 57; 80; 87; 75; 470; Steel; Fairy;
#
# Natural Cure; Frisk; Harvest; ; ; ; Description not available yet; ; ; ; ; 6; 0.4m; 708; Phantump; Stump Pokemon; 70; 48; 43; 50; 60; 38; 309; Ghost; Grass;
#
# Natural Cure; Frisk; Harvest; ; ; ; Description not available yet; ; ; ; ; 6; 1.5m; 709; Trevenant; Elder Tree Pokemon; 110; 76; 85; 65; 82; 56; 474; Ghost; Grass;
#
# Pickup; Frisk; Insomnia; ; ; ; Description not available yet; ; ; ; ; 6; 0.8m; 710; Pumpkaboo; Pumpkin Pokemon; 66; 70; 59; 44; 55; 41; 335; Ghost; Grass;
#
# Pickup; Frisk; Insomnia; ; ; ; Description not available yet; ; ; ; ; 6; 1.7m; 711; Gourgeist; Pumpkin Pokemon; 100; 122; 85; 58; 75; 54; 494; Ghost; Grass;
#
# Own Tempo; Ice Body; Sturdy; ; ; ; Description not available yet; ; ; ; ; 6; ; 712; Bergmite; Ice Chunk Pokemon; 69; 85; 55; 32; 35; 28; 304; Ice; ; 99.5 kg
#
# Own Tempo; Ice Body; Sturdy; ; ; ; Description not available yet; ; ; ; ; 6; ; 713; Avalugg; Iceberg Pokemon; 117; 184; 95; 44; 46; 28; 514; Ice; ;
#
# Frisk; Infiltrator; Telepathy; ; ; ; Description not available yet; ; ; ; ; 6; 0.5m; 714; Noibat; Sound Wave Pokemon; 30; 35; 40; 45; 40; 55; 245; Flying; Dragon;
#
# Frisk; Infiltrator; Telepathy; ; ; ; Description not available yet; ; ; ; ; 6; 1.5m; 715; Noivern; Sound Wave Pokemon; 70; 80; 85; 97; 80; 123; 535; Flying; Dragon;
#
# Fairy Aura; ; ; ; ; ; Description not available yet; ; ; ; ; 6; ; 716; Xerneas; Life Pokemon; 131; 95; 126; 131; 98; 99; 680; Fairy; ;
#
# Dark Aura; ; ; ; ; ; Description not available yet; ; ; ; ; 6; 5.8m; 717; Yveltal; Destruction Pokemon; 131; 95; 126; 131; 98; 99; 680; Dark; Flying;
#
# Aura Break; Power Construct; ; ; ; ; Description not available yet; ; ; ; ; 6; ; 718; Zygarde; Order Pokemon; 100; 121; 216; 91; 95; 85; 708; Dragon; Ground; 284.6 kg
#
# Clear Body; ; ; ; ; ; Description not available yet; ; ; ; ; 6; 0.7m; 719; Diancie; Jewel Pokemon; 160; 110; 50; 160; 110; 110; 700; Rock; Fairy; 8.8 kg
#
# Magician; ; ; ; ; ; Description not available yet; ; ; ; ; 6; ; 720; Hoopa; Mischief Pokemon (Confined)Djinn Pokemonn (Unbound); 160; 60; 80; 170; 130; 80; 680; Psychic; Ghost;
#
# Water Absorb; ; ; ; ; ; Description not available yet; ; ; ; ; 6; 1.7m; 721; Volcanion; Steam Pokemon; 110; 120; 80; 130; 90; 70; 600; Fire; Water;
#
# Overgrow; Long Reach; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 722; Rowlet; Grass Quill Pokemon; 55; 55; 68; 50; 50; 42; 320; Grass; Flying; 1.5 kg
#
# Overgrow; Long Reach; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.7m; 723; Dartrix; Blade Quill Pokemon; 75; 75; 78; 70; 70; 52; 420; Grass; Flying;
#
# Overgrow; Long Reach; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.6m; 724; Decidueye; Arrow Quill Pokemon; 107; 75; 78; 100; 100; 70; 530; Grass; Ghost; 36.6 kg
#
# Blaze; Intimidate; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 725; Litten; Fire Cat Pokemon; 65; 40; 45; 60; 40; 70; 320; Fire; ; 4.3 kg
#
# Blaze; Intimidate; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.7m; 726; Torracat; Fire Cat Pokemon; 85; 50; 65; 80; 50; 90; 420; Fire; ;
#
# Blaze; Intimidate; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.8m; 727; Incineroar; Heel Pokemon; 115; 90; 95; 80; 90; 60; 530; Fire; Dark;
#
# Torrent; Liquid Voice; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 728; Popplio; Sea Lion Pokemon; 54; 54; 50; 66; 56; 40; 320; Water; ; 7.5 kg
#
# Torrent; Liquid Voice; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 729; Brionne; Pop Star Pokemon; 69; 69; 60; 91; 81; 50; 420; Water; ; 17.5 kg
#
# Torrent; Liquid Voice; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.8m; 730; Primarina; Soloist Pokemon; 74; 74; 80; 126; 116; 60; 530; Water; Fairy;
#
# Keen Eye; Skill Link; Pickup; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 731; Pikipek; Woodpecker Pokemon; 75; 30; 35; 30; 30; 65; 265; Normal; Flying; 1.2 kg
#
# Keen Eye; Skill Link; Pickup; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 732; Trumbeak; Bugle Beak Pokemon; 85; 50; 55; 40; 50; 75; 355; Normal; Flying; 14.8 kg
#
# Keen Eye; Skill Link; Sheer Force; ; ; ; Description not available yet; ; ; ; ; 7; 1.1m; 733; Toucannon; Cannon Pokemon; 120; 75; 80; 75; 75; 60; 485; Normal; Flying;
#
# Stakeout; Strong Jaw; Adaptability; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 734; Yungoos; Loitering Pokemon; 70; 30; 48; 30; 30; 45; 253; Normal; ;
#
# Stakeout; Strong Jaw; Adaptability; ; ; ; Description not available yet; ; ; ; ; 7; 0.7m; 735; Gumshoos; Stakeout Pokemon; 110; 60; 88; 55; 60; 45; 418; Normal; ; 14.2 kg
#
# Swarm; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 736; Grubbin; Larva Pokemon; 62; 45; 47; 55; 45; 46; 300; Bug; ; 4.4 kg
#
# Battery; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.5m; 737; Charjabug; Battery Pokemon; 82; 95; 57; 55; 75; 36; 400; Bug; Electric; 10.5 kg
#
# Levitate; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.5m; 738; Vikavolt; Stag Beetle Pokemon; 70; 90; 77; 145; 75; 43; 500; Bug; Electric;
#
# Hyper Cutter; Iron Fist; Anger Point; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 739; Crabrawler; Boxing Pokemon; 82; 57; 47; 42; 47; 63; 338; Fighting; ;
#
# Hyper Cutter; Iron Fist; Anger Point; ; ; ; Description not available yet; ; ; ; ; 7; 1.7m; 740; Crabominable; Woolly Crab Pokemon; 132; 77; 97; 62; 67; 43; 478; Fighting; Ice;
#
# Dancer; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 741; Oricorio; Dancing Pokemon; 70; 70; 75; 98; 70; 93; 476; Fire; Flying; 3.4 kg
#
# Honey Gather; Shield Dust; Sweet Veil; ; ; ; Description not available yet; ; ; ; ; 7; 0.1m; 742; Cutiefly; Bee Fly Pokemon; 45; 40; 40; 55; 40; 84; 304; Bug; Fairy; 0.2 kg
#
# Honey Gather; Shield Dust; Sweet Veil; ; ; ; Description not available yet; ; ; ; ; 7; 0.2m; 743; Ribombee; Bee Fly Pokemon; 55; 60; 60; 95; 70; 124; 464; Bug; Fairy; 0.5 kg
#
# Keen Eye; Vital Spirit; Steadfast; ; ; ; Description not available yet; ; ; ; ; 7; 0.5m; 744; Rockruff; Puppy Pokemon; 65; 40; 45; 30; 40; 60; 280; Rock; ; 9.2 kg
#
# Keen Eye; Sand Rush; Steadfast; Keen Eye; Vital Spirit; No Guard; Description not available yet; ; ; ; ; 7; ; 745; Lycanroc; Wolf Pokemon; 115; 75; 85; 55; 75; 82; 487; Rock; ;
#
# Schooling; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.2m; 746; Wishiwashi; Small Fry Pokemon; 140; 130; 45; 140; 135; 30; 620; Water; ; 0.3 kg
#
# Merciless; Limber; Regenerator; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 747; Mareanie; Brutal Star Pokemon; 53; 62; 50; 43; 52; 45; 305; Poison; Water;
#
# Merciless; Limber; Regenerator; ; ; ; Description not available yet; ; ; ; ; 7; 0.7m; 748; Toxapex; Brutal Star Pokemon; 63; 152; 50; 53; 142; 35; 495; Poison; Water; 14.5 kg
#
# Own Tempo; Stamina; Inner Focus; ; ; ; Description not available yet; ; ; ; ; 7; ; 749; Mudbray; Donkey Pokemon; 100; 70; 70; 45; 55; 45; 385; Ground; ;
#
# Own Tempo; Stamina; Inner Focus; ; ; ; Description not available yet; ; ; ; ; 7; 2.5m; 750; Mudsdale; Draft Horse Pokemon; 125; 100; 100; 55; 85; 35; 500; Ground; ;
#
# Water Bubble; Water Absorb; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 751; Dewpider; Water Bubble Pokemon; 40; 52; 38; 40; 72; 27; 269; Water; Bug;
#
# Water Bubble; Water Absorb; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.8m; 752; Araquanid; Water Bubble Pokemon; 70; 92; 68; 50; 132; 42; 454; Water; Bug;
#
# Leaf Guard; Contrary; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 753; Fomantis; Sickle Grass Pokemon; 55; 35; 40; 50; 35; 35; 250; Grass; ; 1.5 kg
#
# Leaf Guard; Contrary; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.9m; 754; Lurantis; Bloom Sickle Pokemon; 105; 90; 70; 80; 90; 45; 480; Grass; ; 18.5 kg
#
# Illuminate; Effect Spore; Rain Dish; ; ; ; Description not available yet; ; ; ; ; 7; 0.2m; 755; Morelull; Illuminating Pokemon; 35; 55; 40; 65; 75; 15; 285; Grass; Fairy; 1.5 kg
#
# Illuminate; Effect Spore; Rain Dish; ; ; ; Description not available yet; ; ; ; ; 7; ; 756; Shiinotic; Illuminating Pokemon; 45; 80; 60; 90; 100; 30; 405; Grass; Fairy; 11.5 kg
#
# Corrosion; Oblivious; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 757; Salandit; Toxic Lizard Pokemon; 44; 40; 48; 71; 40; 77; 320; Poison; Fire; 4.8 kg
#
# Corrosion; Oblivious; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.2m; 758; Salazzle; Toxic Lizard Pokemon; 64; 60; 68; 111; 60; 117; 480; Poison; Fire; 22.2 kg
#
# Fluffy; Klutz; Cute Charm; ; ; ; Description not available yet; ; ; ; ; 7; 0.5m; 759; Stufful; Flailing Pokemon; 75; 50; 70; 45; 50; 50; 340; Normal; Fighting; 6.8 kg
#
# Fluffy; Klutz; Unnerve; ; ; ; Description not available yet; ; ; ; ; 7; 2.1m; 760; Bewear; Strong Arm Pokemon; 125; 80; 120; 55; 60; 60; 500; Normal; Fighting;
#
# Leaf Guard; Oblivious; Sweet Veil; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 761; Bounsweet; Fruit Pokemon; 30; 38; 42; 30; 38; 32; 210; Grass; ; 3.2 kg
#
# Leaf Guard; Oblivious; Sweet Veil; ; ; ; Description not available yet; ; ; ; ; 7; 0.7m; 762; Steenee; Fruit Pokemon; 40; 48; 52; 40; 48; 62; 290; Grass; ; 8.2 kg
#
# Leaf Guard; Queenly Majesty; Sweet Veil; ; ; ; Description not available yet; ; ; ; ; 7; 1.2m; 763; Tsareena; Fruit Pokemon; 120; 98; 72; 50; 98; 72; 510; Grass; ; 21.4 kg
#
# Flower Veil; Triage; Natural Cure; ; ; ; Description not available yet; ; ; ; ; 7; 0.1m; 764; Comfey; Posy Picker Pokemon; 52; 90; 51; 82; 110; 100; 485; Fairy; ; 0.3 kg
#
# Inner Focus; Telepathy; Symbiosis; ; ; ; Description not available yet; ; ; ; ; 7; 1.5m; 765; Oranguru; Sage Pokemon; 60; 80; 90; 90; 110; 60; 490; Normal; Psychic;
#
# Receiver; Defiant; ; ; ; ; Description not available yet; ; ; ; ; 7; ; 766; Passimian; Teamwork Pokemon; 120; 90; 100; 40; 60; 80; 490; Fighting; ; 82.8 kg
#
# Wimp Out; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.5m; 767; Wimpod; Turn Tail Pokemon; 35; 40; 25; 20; 30; 80; 230; Bug; Water;
#
# Emergency Exit; ; ; ; ; ; Description not available yet; ; ; ; ; 7; ; 768; Golisopod; Hard Scale Pokemon; 125; 140; 75; 60; 90; 40; 530; Bug; Water;
#
# Water Compaction; Sand Veil; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.5m; 769; Sandygast; Sand Heap Pokemon; 55; 80; 55; 70; 45; 15; 320; Ghost; Ground;
#
# Water Compaction; Sand Veil; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.3m; 770; Palossand; Sand Castle Pokemon; 75; 110; 85; 100; 75; 35; 480; Ghost; Ground;
#
# Innards Out; Unaware; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 771; Pyukumuku; Sea Cucumber Pokemon; 60; 130; 55; 30; 130; 5; 410; Water; ; 1.2 kg
#
# Battle Armor; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.9m; 772; Type: Null; Synthetic Pokemon; 95; 95; 95; 95; 95; 59; 534; Normal; ; 120.5 kg
#
# RKS System; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 2.3m; 773; Silvally; Synthetic Pokemon; 95; 95; 95; 95; 95; 95; 570; Normal; ; 100.5 kg
#
# Shields Down; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 774; Minior; Meteor Pokemon; 100; 60; 60; 100; 60; 120; 500; Rock; Flying;
#
# Comatose; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.4m; 775; Komala; Drowsing Pokemon; 115; 65; 65; 75; 95; 65; 480; Normal; ; 19.9 kg
#
# Shell Armor; ; ; ; ; ; Description not available yet; ; ; ; ; 7; ; 776; Turtonator; Blast Turtle Pokemon; 78; 135; 60; 91; 85; 36; 485; Fire; Dragon;
#
# Iron Barbs; Lightningrod; Sturdy; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 777; Togedemaru; Roly-Poly Pokemon; 98; 63; 65; 40; 73; 96; 435; Electric; Steel; 3.3 kg
#
# Disguise; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.2m; 778; Mimikyu; Disguise Pokemon; 90; 80; 55; 50; 105; 96; 476; Ghost; Fairy; 0.7 kg
#
# Dazzling; Strong Jaw; Wonder Skin ; ; ; ; Description not available yet; ; ; ; ; 7; 0.9m; 779; Bruxish; Gnash Teeth Pokemon; 105; 70; 68; 70; 70; 92; 475; Water; Psychic;
#
# Berserk; Sap Sipper; Cloud Nine; ; ; ; Description not available yet; ; ; ; ; 7; ; 780; Drampa; Placid Pokemon; 60; 85; 78; 135; 91; 36; 485; Normal; Dragon;
#
# Steelworker; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 3.9m; 781; Dhelmise; Sea Creeper Pokemon; 131; 100; 70; 86; 90; 40; 517; Ghost; Grass;
#
# Bulletproof; Soundproof; Overcoat; ; ; ; Description not available yet; ; ; ; ; 7; 0.6m; 782; Jangmo-o; Scaly Pokemon; 55; 65; 45; 45; 45; 45; 300; Dragon; ; 29.7 kg
#
# Bulletproof; Soundproof; Overcoat; ; ; ; Description not available yet; ; ; ; ; 7; 1.2m; 783; Hakamo-o; Scaly Pokemon; 75; 90; 55; 65; 70; 65; 420; Dragon; Fighting;
#
# Bulletproof; Soundproof; Overcoat; ; ; ; Description not available yet; ; ; ; ; 7; 1.6m; 784; Kommo-o; Scaly Pokemon; 110; 125; 75; 100; 105; 85; 600; Dragon; Fighting; 78.2 kg
#
# Electric Surge; Telepathy; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.8m; 785; Tapu Koko; Land Spirit Pokemon; 115; 85; 70; 95; 75; 130; 570; Electric; Fairy; 20.5 kg
#
# Psychic Surge; Telepathy; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.2m; 786; Tapu Lele; Land Spirit Pokemon; 85; 75; 70; 130; 115; 95; 570; Psychic; Fairy; 18.6 kg
#
# Grassy Surge; Telepathy; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.9m; 787; Tapu Bulu; Land Spirit Pokemon; 130; 115; 70; 85; 95; 75; 570; Grass; Fairy; 45.5 kg
#
# Misty Surge; Telepathy; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.3m; 788; Tapu Fini; Land Spirit Pokemon; 75; 115; 70; 95; 130; 85; 570; Water; Fairy; 21.2 kg
#
# Unaware; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.2m; 789; Cosmog; Nebula Pokemon; 29; 31; 43; 29; 31; 37; 200; Psychic; ; 0.1 kg
#
# Sturdy; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.1m; 790; Cosmoem; Protostar Pokemon; 29; 131; 43; 29; 131; 37; 400; Psychic; ; 999.9 kg
#
# Full Metal Body; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 3.4m; 791; Solgaleo; Sunne Pokemon; 137; 107; 137; 113; 89; 97; 680; Psychic; Steel;
#
# Shadow Shield; ; ; ; ; ; Description not available yet; ; ; ; ; 7; ; 792; Lunala; Moone Pokemon; 113; 89; 137; 137; 107; 97; 680; Psychic; Ghost;
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.2m; 793; Nihilego; Parasite Pokemon; 53; 47; 109; 127; 131; 103; 570; Rock; Poison; 55.5 kg
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 2.4m; 794; Buzzwole; Swollen Pokemon; 139; 139; 107; 53; 53; 79; 570; Bug; Fighting; 333.6 kg
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 1.8m; 795; Pheromosa; Lissome Pokemon; 137; 37; 71; 137; 37; 151; 570; Bug; Fighting;
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 3.8m; 796; Xurkitree; Glowing Pokemon; 89; 71; 83; 173; 71; 83; 570; Electric; ;
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 9.2m; 797; Celesteela; Launch Pokemon; 101; 103; 97; 107; 101; 61; 570; Steel; Flying; 999.9 kg
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 0.3m; 798; Kartana; Drawn Sword Pokemon; 181; 131; 59; 59; 31; 109; 570; Grass; Steel; 0.1 kg
#
# Beast Boost; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 5.5m; 799; Guzzlord; Junkivore Pokemon; 101; 53; 223; 97; 53; 43; 570; Dark; Dragon;
#
# Prism Armor; ; ; ; ; ; Description not available yet; ; ; ; ; 7; 2.4m; 800; Necrozma; Prism Pokemon; 107; 101; 97; 127; 89; 79; 600; Psychic; ;
#
# Soul-Heart; ; ; ; ; ; Description not available yet; ; ; ; ; 7; ; 801; Magearna; Artificial Pokemon; 95; 115; 80; 130; 115; 65; 600; Steel; Fairy; 80.5 kg
